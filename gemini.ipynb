# %% [markdown]
# <a href="https://colab.research.google.com/github/usmanshabbir756/EMS-Backend/blob/master/gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# today i am learning gemini ai with phython

# %% [markdown]
# google offer one gpu free and tpu free
# cpu: central process unit
# gpu:graphic
# tpu:tensor

# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
# !pip install google-generativeai

# %%
import os
import google.generativeai as genai
api_Key="AIzaSyC_gaqXD4us6qlR8ngpcu7eUDwmwiDqaDA"
genai.configure(api_key=api_Key)
# we are accessing google gemeni ai

# %%
for m in genai.list_models():
  print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision
# models/embedding-001
# models/aqa

# %% [markdown]
# Text model : Gemini-pro

# %%
model=genai.GenerativeModel("gemini-pro")
model
# Out:
#  genai.GenerativeModel(
#    model_name='models/gemini-pro',
#    generation_config={}.
#    safety_settings={}
# )

# %%
response = model.generate_content("List of top 5 pakistani criketers")
print(response.text)
# Out:
# 1. Imran Khan
# 2. Wasim Akram
# 3. Javed Miandad
# 4. Inzamam-ul-Haq
# 5. Shahid Afridi

# %%
response = model.generate_content("why they are in top")
print(response.text)
# Out:
# **There are several reasons why a certain group or individual may be considered to be "on top." Here are some of the most common:**
#
# * **Achievement:** They have achieved a high level of success in their chosen field, whether it be business, politics, entertainment, sports, or another area.
# * **Influence:** They have a significant impact on the decisions and actions of others, either through their personal charisma, their financial resources, or their political power.
# * **Wealth:** They have accumulated a substantial amount of wealth, which often gives them access to privileges and opportunities that others do not have.
# * **Status:** They have achieved a high social status, which may be based on their family background, their education, their profession, or other factors.
# * **Popularity:** They are widely known and admired by the public, often due to their achievements, their charisma, or their involvement in popular culture.
# ...

# %%
import os
import google.generativeai as genai
api_key="AIzaSyC_gaqXD4us6qlR8ngpcu7eUDwmwiDqaDA"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-pro")

response = model.generate_content("write a poem")
print(response.text)
# Out:
# **Whispers of the Night**
#
# As darkness paints the sky with hue,
# Whispers echo through the night's embrace.
# Softly carried by the zephyrs, too,
# Secrets untold, mysteries to chase.
#
# The moon, a lantern, guides my way,
# Through shadows dancing, secrets to find.
# Trees sway gently, casting shadows grey,
# As whispers linger, whispering my mind.
#
# The wind whispers tales of distant lands,
# Of wonders seen and stories yet to unfold.
# The stars, like diamonds, upon the strands,
# A constellation of whispers to behold.
#
# Nature's symphony, a gentle hum,
# Whispers of the night, an ancient song.
# As silence reigns, my heart becomes undone,
# Lost in the whispers that lead me along.
#
# For in the night's embrace, I find release,
# From worries that have burdened my weary soul.
# Whispers of the night, bring me peace,
# A sanctuary where secrets take control.
#
# So let the darkness hold me close,
# As whispers guide me through the realm of night.
# ...

# %%
from PIL import Image   #Pakage name pillow

# %%
img=Image.open("/content/my.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=715x585>

# %%
import os
import google.generativeai as genai
api_key="AIzaSyC_gaqXD4us6qlR8ngpcu7eUDwmwiDqaDA"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="What are the objects in the given image"
response=model.generate_content([prompt,img])
print(response.text)
# Out:
#  The objects in the given image are:
#
# A photo of a man in a suit
# A text box containing the man's name and job title
# A list of the man's skills
# A list of the man's projects
# A map showing the man's location
# A calendar showing the man's availability
# A list of the man's achievements
# A list of the man's organizations

# %%
import os
import google.generativeai as genai
api_key="AIzaSyC_gaqXD4us6qlR8ngpcu7eUDwmwiDqaDA"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="caption the image"
response=model.generate_content([prompt,img])
print(response.text)
# Out:
#  A software engineer's GitHub profile with a detailed description of their skills, experience, and projects.

# %%
import os
import google.generativeai as genai
api_key="AIzaSyC_gaqXD4us6qlR8ngpcu7eUDwmwiDqaDA"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="write a poem"
response=model.generate_content([prompt,img])
print(response.text)
# Out:
#  In the realm of code, where logic intertwines,
# There's a mind that unravels, a coder's design.
# With nimble fingers and a thirst for the new,
# Usman Shabbir emerges, his passion shines through.
#
# From Java's embrace to Python's allure,
# His expertise dances, painting code secure.
# Full-stack prowess, a symphony of skill,
# In every project, he leaves an indelible thrill.
#
# JavaScript's ballet, he conducts with grace,
# Breathing life into visions, at a swift pace.
# React and Java, his trusted companions,
# Together they forge, defying limitations.
#
# But it's not just the languages he commands,
# It's the way he thinks, the way he understands.
# An insatiable hunger for knowledge untold,
# In algorithms and data, his mind takes hold.
#
# On GitHub, his playground, his haven of code,
# Commits and contributions, a testament to hisロード.
# A coder's journey, a tale yet unfurled,
# With each line of code, a masterpiece unfurled.
#
# ...

# %% [markdown]
# Create Application

# %%
# !pip install streamlit
# !npm install localtunel
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 29.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...
# npm ERR! code E404
# npm ERR! 404 Not Found - GET https://registry.npmjs.org/localtunel - Not found
# npm ERR! 404
# npm ERR! 404  'localtunel@latest' is not in the npm registry.
# npm ERR! 404 You should bug the author to publish it (or use the name yourself!)
# npm ERR! 404
# npm ERR! 404 Note that you can also install from a
# ...

# %%
# %%writefile app.py
#import required pakages
import streamlit as st
import google.generativeai as genai
from PIL import Image

#### provide apiKey
api_key="AIzaSyC_gaqXD4us6qlR8ngpcu7eUDwmwiDqaDA"
genai.configure(api_key=api_key)

#### choose the heading
st.header("Image analytics")

######## upload file
uploaded_file=st.file_uploader("upload an image",type=["png","jpg", "jpeg"])
if uploaded_file is not None:
    st.image(Image.open(uploaded_file))

####### what you want to ask
prompt= st.text_input("Enter the text")

####### use genai skill

if(st.button("Get Response")):
    img=Image.open(uploaded_file)
    model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
    response=model.generate_content([prompt,img])
    st.markdown(response.text)
# Out:
# Overwriting app.py

# %%
# !streamlit run /content/app.py & npx localtunel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.80.176.56
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.80.176.56:8501
#
# npm ERR! code E404
# npm ERR! 404 Not Found - GET https://registry.npmjs.org/localtunel - Not found
# npm ERR! 404
# npm ERR! 404  'localtunel@latest' is not in the npm registry.
# npm ERR! 404 You should bug the author to publish it (or use the name yourself!)
# npm ERR! 404
# npm ERR! 404 Note that you can also install from a
# npm ERR! 404 tarball, folder, http url, or git url.
#
# npm ERR! A complete log of this run can be found in:
# npm ERR!     /root/.npm/_logs/2024-03-24T06_38_47_377Z-debug.log
# Install for [ 'localtunel@latest' ] failed with code 1
#   Stopping...

# %%
# !streamlit run /content/app.py & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.80.176.56
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.80.176.56:8501
#
# npx: installed 22 in 3.191s
# your url is: https://shaky-clowns-tell.loca.lt
#   Stopping...

# %%
# %%writefile app.py
######## Import the required pacakges ############
import streamlit as st
import google.generativeai as genai
from PIL import Image

####### Provide your api key ###################
api_key="AIzaSyBUUejpbU_3eouCT96lkHmkE2mQ6jQb8TU"
genai.configure(api_key=api_key)

######## Choose the heading ###############
st.header("Image analytics")

########## Upload a file ##################
uploaded_file=st.file_uploader("Upload an image",type=["png","jpg","jpeg"])

if uploaded_file is not None:
    st.image(Image.open(uploaded_file))

############ What you want ask ####################
prompt=st.text_input("Enter the text")

######### Use genai skill ##########################

if st.button("GET RESPONSE"):
    img=Image.open(uploaded_file)
    model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
    response=model.generate_content([prompt,img])
    st.markdown(response.text)
# Out:
# Writing app.py

# %%
# !streamlit run /content/app.py & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.80.176.56
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.80.176.56:8501
#
# npx: installed 22 in 2.243s
# your url is: https://silent-beds-jog.loca.lt
